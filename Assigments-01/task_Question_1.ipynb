# %%
#Q1.
skills = {
    'Python':1.0,
    'SQL':0.9,
    'MAchine Learning':0.8,
    'Deep learning': 0.5,
    'Power Bi':0.6,
    'Statistics':0.7
}
# print(skills)

order_skills = sorted([(i,j) for i, j in skills.items()],key = lambda x:x[1],reverse = True)

# print(sort_skills)

for i,j in order_skills:
    # print(i,j)
    print(f"{i:<12}{j:0%}")
# Out:
# Python      100.000000%
# SQL         90.000000%
# MAchine Learning80.000000%
# Statistics  70.000000%
# Power Bi    60.000000%
# Deep learning50.000000%
